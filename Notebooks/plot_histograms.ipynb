# %%
import numpy as np
import math
import matplotlib.pyplot as plt

# %% [markdown]
# ### McCaffrey

# %%
mixtures = ['M1', 'M2', 'M3', 'M4', 'M5', 'M6', 'M7', 'M8', 'M9', 'M10']
folder = '../Results/NGS_J19_DRK/McCaffrey/'

plt.style.use('stylesheet.mpltstyle_histograms')
fig, axes = plt.subplots(4, 3, figsize = (4.3, 5))

m = 0
x = math.ceil((m+1)/3)-1
y = (m % 3)
data = np.loadtxt(folder+'Ait_distances_'+str(m)+'.txt')
axes[x,y].hist(data, bins = 30)
axes[x,y].annotate('M'+str(m+1), xy=(0.05, 0.9), xycoords="axes fraction", weight='bold')
axes[x,y].text(0.65, 0.9, r'$\mu=$'+str(round(np.nanmean(data),2)), transform=axes[x,y].transAxes)
axes[x,y].text(0.65, 0.8, r'$\sigma^2=$'+str(round(np.nanvar(data),3)), transform=axes[x,y].transAxes)
axes[x,y].set_ylabel('Frequency')

m = 1
x = math.ceil((m+1)/3)-1
y = (m % 3)
data = np.loadtxt(folder+'Ait_distances_'+str(m)+'.txt')
axes[x,y].hist(data, bins = 30)
axes[x,y].annotate('M'+str(m+1), xy=(0.05, 0.9), xycoords="axes fraction", weight='bold')
axes[x,y].text(0.65, 0.9, r'$\mu=$'+str(round(np.nanmean(data),2)), transform=axes[x,y].transAxes)
axes[x,y].text(0.65, 0.8, r'$\sigma^2=$'+str(round(np.nanvar(data),3)), transform=axes[x,y].transAxes)

m = 2
x = math.ceil((m+1)/3)-1
y = (m % 3)
data = np.loadtxt(folder+'Ait_distances_'+str(m)+'.txt')
axes[x,y].hist(data, bins = 30)
axes[x,y].annotate('M'+str(m+1), xy=(0.05, 0.9), xycoords="axes fraction", weight='bold')
axes[x,y].text(0.65, 0.9, r'$\mu=$'+str(round(np.nanmean(data),2)), transform=axes[x,y].transAxes)
axes[x,y].text(0.65, 0.8, r'$\sigma^2=$'+str(round(np.nanvar(data),3)), transform=axes[x,y].transAxes)

m = 3
x = math.ceil((m+1)/3)-1
y = (m % 3)
data = np.loadtxt(folder+'Ait_distances_'+str(m)+'.txt')
axes[x,y].hist(data, bins = 30)
axes[x,y].annotate('M'+str(m+1), xy=(0.05, 0.9), xycoords="axes fraction", weight='bold')
axes[x,y].text(0.65, 0.9, r'$\mu=$'+str(round(np.nanmean(data),2)), transform=axes[x,y].transAxes)
axes[x,y].text(0.65, 0.8, r'$\sigma^2=$'+str(round(np.nanvar(data),3)), transform=axes[x,y].transAxes)
axes[x,y].set_ylabel('Frequency')

m = 4
x = math.ceil((m+1)/3)-1
y = (m % 3)
data = np.loadtxt(folder+'Ait_distances_'+str(m)+'.txt')
axes[x,y].hist(data, bins = 30)
axes[x,y].annotate('M'+str(m+1), xy=(0.05, 0.9), xycoords="axes fraction", weight='bold')
axes[x,y].text(0.65, 0.9, r'$\mu=$'+str(round(np.nanmean(data),2)), transform=axes[x,y].transAxes)
axes[x,y].text(0.65, 0.8, r'$\sigma^2=$'+str(round(np.nanvar(data),3)), transform=axes[x,y].transAxes)

m = 5
x = math.ceil((m+1)/3)-1
y = (m % 3)
data = np.loadtxt(folder+'Ait_distances_'+str(m)+'.txt')
axes[x,y].hist(data, bins = 30)
axes[x,y].annotate('M'+str(m+1), xy=(0.05, 0.9), xycoords="axes fraction", weight='bold')
axes[x,y].text(0.65, 0.9, r'$\mu=$'+str(round(np.nanmean(data),2)), transform=axes[x,y].transAxes)
axes[x,y].text(0.65, 0.8, r'$\sigma^2=$'+str(round(np.nanvar(data),3)), transform=axes[x,y].transAxes)

m = 6
x = math.ceil((m+1)/3)-1
y = (m % 3)
data = np.loadtxt(folder+'Ait_distances_'+str(m)+'.txt')
axes[x,y].hist(data, bins = 30)
axes[x,y].annotate('M'+str(m+1), xy=(0.8, 0.9), xycoords="axes fraction", weight='bold')
axes[x,y].text(0.1, 0.9, r'$\mu=$'+str(round(np.nanmean(data),2)), transform=axes[x,y].transAxes)
axes[x,y].text(0.1, 0.8, r'$\sigma^2=$'+str(round(np.nanvar(data),3)), transform=axes[x,y].transAxes)
axes[x,y].set_ylabel('Frequency')

m = 7
x = math.ceil((m+1)/3)-1
y = (m % 3)
data = np.loadtxt(folder+'Ait_distances_'+str(m)+'.txt')
axes[x,y].hist(data, bins = 30)
axes[x,y].annotate('M'+str(m+1), xy=(0.8, 0.9), xycoords="axes fraction", weight='bold')
axes[x,y].text(0.1, 0.9, r'$\mu=$'+str(round(np.nanmean(data),2)), transform=axes[x,y].transAxes)
axes[x,y].text(0.1, 0.8, r'$\sigma^2=$'+str(round(np.nanvar(data),3)), transform=axes[x,y].transAxes)
axes[x,y].set_xlabel('Aitchison Distance \n'r'$d_a(\mathbf{\hat{x}}_{Mc},\mathbf{x}^{*})$')

m = 8
x = math.ceil((m+1)/3)-1
y = (m % 3)
data = np.loadtxt(folder+'Ait_distances_'+str(m)+'.txt')
axes[x,y].hist(data, bins = 30)
axes[x,y].annotate('M'+str(m+1), xy=(0.05, 0.9), xycoords="axes fraction", weight='bold')
axes[x,y].text(0.65, 0.9, r'$\mu=$'+str(round(np.nanmean(data),2)), transform=axes[x,y].transAxes)
axes[x,y].text(0.65, 0.8, r'$\sigma^2=$'+str(round(np.nanvar(data),3)), transform=axes[x,y].transAxes)
axes[x,y].set_xlabel('Aitchison Distance \n'r'$d_a(\mathbf{\hat{x}}_{Mc},\mathbf{x}^{*})$')

m = 9
x = math.ceil((m+1)/3)-1
y = (m % 3)
data = np.loadtxt(folder+'Ait_distances_'+str(m)+'.txt')
axes[x,y].hist(data, bins = 30)
axes[x,y].annotate('M'+str(m+1), xy=(0.8, 0.9), xycoords="axes fraction", weight='bold')
axes[x,y].text(0.1, 0.9, r'$\mu=$'+str(round(np.nanmean(data),2)), transform=axes[x,y].transAxes)
axes[x,y].text(0.1, 0.8, r'$\sigma^2=$'+str(round(np.nanvar(data),3)), transform=axes[x,y].transAxes)
axes[x,y].set_ylabel('Frequency')
axes[x,y].set_xlabel('Aitchison Distance \n'r'$d_a(\mathbf{\hat{x}}_{Mc},\mathbf{x}^{*})$')


axes[3,1].axis('off')
axes[3,2].axis('off')
plt.savefig('../Figures/McCaffrey_hist.pdf')
plt.show()

# %% [markdown]
# ### PGM

# %%
mixtures = ['M1', 'M2', 'M3', 'M4', 'M5', 'M6', 'M7', 'M8', 'M9', 'M10']
folder = '../Results/NGS_J19_DRK/PGM/'

plt.style.use('stylesheet.mpltstyle_histograms')
fig, axes = plt.subplots(4, 3, figsize = (4.3, 5))

m = 0
x = math.ceil((m+1)/3)-1
y = (m % 3)
data = np.loadtxt(folder+'Ait_distances_'+str(m)+'.txt')
axes[x,y].hist(data, bins = 30)
axes[x,y].annotate('M'+str(m+1), xy=(0.05, 0.9), xycoords="axes fraction", weight='bold')
axes[x,y].text(0.65, 0.9, r'$\mu=$'+str(round(np.nanmean(data),2)), transform=axes[x,y].transAxes)
axes[x,y].text(0.65, 0.8, r'$\sigma^2=$'+str(round(np.nanvar(data),3)), transform=axes[x,y].transAxes)
axes[x,y].set_ylabel('Frequency')

m = 1
x = math.ceil((m+1)/3)-1
y = (m % 3)
data = np.loadtxt(folder+'Ait_distances_'+str(m)+'.txt')
axes[x,y].hist(data, bins = 30)
axes[x,y].annotate('M'+str(m+1), xy=(0.05, 0.9), xycoords="axes fraction", weight='bold')
axes[x,y].text(0.65, 0.9, r'$\mu=$'+str(round(np.nanmean(data),2)), transform=axes[x,y].transAxes)
axes[x,y].text(0.65, 0.8, r'$\sigma^2=$'+str(round(np.nanvar(data),3)), transform=axes[x,y].transAxes)

m = 2
x = math.ceil((m+1)/3)-1
y = (m % 3)
data = np.loadtxt(folder+'Ait_distances_'+str(m)+'.txt')
axes[x,y].hist(data, bins = 30)
axes[x,y].annotate('M'+str(m+1), xy=(0.05, 0.9), xycoords="axes fraction", weight='bold')
axes[x,y].text(0.65, 0.9, r'$\mu=$'+str(round(np.nanmean(data),2)), transform=axes[x,y].transAxes)
axes[x,y].text(0.65, 0.8, r'$\sigma^2=$'+str(round(np.nanvar(data),3)), transform=axes[x,y].transAxes)

m = 3
x = math.ceil((m+1)/3)-1
y = (m % 3)
data = np.loadtxt(folder+'Ait_distances_'+str(m)+'.txt')
axes[x,y].hist(data, bins = 30)
axes[x,y].annotate('M'+str(m+1), xy=(0.05, 0.9), xycoords="axes fraction", weight='bold')
axes[x,y].text(0.65, 0.9, r'$\mu=$'+str(round(np.nanmean(data),2)), transform=axes[x,y].transAxes)
axes[x,y].text(0.65, 0.8, r'$\sigma^2=$'+str(round(np.nanvar(data),3)), transform=axes[x,y].transAxes)
axes[x,y].set_ylabel('Frequency')

m = 4
x = math.ceil((m+1)/3)-1
y = (m % 3)
data = np.loadtxt(folder+'Ait_distances_'+str(m)+'.txt')
axes[x,y].hist(data, bins = 30)
axes[x,y].annotate('M'+str(m+1), xy=(0.05, 0.9), xycoords="axes fraction", weight='bold')
axes[x,y].text(0.65, 0.9, r'$\mu=$'+str(round(np.nanmean(data),2)), transform=axes[x,y].transAxes)
axes[x,y].text(0.65, 0.8, r'$\sigma^2=$'+str(round(np.nanvar(data),3)), transform=axes[x,y].transAxes)

m = 5
x = math.ceil((m+1)/3)-1
y = (m % 3)
data = np.loadtxt(folder+'Ait_distances_'+str(m)+'.txt')
axes[x,y].hist(data, bins = 30)
axes[x,y].annotate('M'+str(m+1), xy=(0.05, 0.9), xycoords="axes fraction", weight='bold')
axes[x,y].text(0.65, 0.9, r'$\mu=$'+str(round(np.nanmean(data),2)), transform=axes[x,y].transAxes)
axes[x,y].text(0.65, 0.8, r'$\sigma^2=$'+str(round(np.nanvar(data),3)), transform=axes[x,y].transAxes)

m = 6
x = math.ceil((m+1)/3)-1
y = (m % 3)
data = np.loadtxt(folder+'Ait_distances_'+str(m)+'.txt')
axes[x,y].hist(data, bins = 30)
axes[x,y].annotate('M'+str(m+1), xy=(0.1, 0.9), xycoords="axes fraction", weight='bold')
axes[x,y].text(0.65, 0.9, r'$\mu=$'+str(round(np.nanmean(data),2)), transform=axes[x,y].transAxes)
axes[x,y].text(0.65, 0.8, r'$\sigma^2=$'+str(round(np.nanvar(data),3)), transform=axes[x,y].transAxes)
axes[x,y].set_ylabel('Frequency')

m = 7
x = math.ceil((m+1)/3)-1
y = (m % 3)
data = np.loadtxt(folder+'Ait_distances_'+str(m)+'.txt')
axes[x,y].hist(data, bins = 30)
axes[x,y].annotate('M'+str(m+1), xy=(0.8, 0.9), xycoords="axes fraction", weight='bold')
axes[x,y].text(0.1, 0.9, r'$\mu=$'+str(round(np.nanmean(data),2)), transform=axes[x,y].transAxes)
axes[x,y].text(0.1, 0.8, r'$\sigma^2=$'+str(round(np.nanvar(data),3)), transform=axes[x,y].transAxes)
axes[x,y].set_xlabel('Aitchison Distance \n'r'$d_a(\mathbf{\hat{x}}_{PGM},\mathbf{x}^{*})$')

m = 8
x = math.ceil((m+1)/3)-1
y = (m % 3)
data = np.loadtxt(folder+'Ait_distances_'+str(m)+'.txt')
axes[x,y].hist(data, bins = 30)
axes[x,y].annotate('M'+str(m+1), xy=(0.05, 0.9), xycoords="axes fraction", weight='bold')
axes[x,y].text(0.5, 0.2, r'$\mu=$'+str(round(np.nanmean(data),2)), transform=axes[x,y].transAxes)
axes[x,y].text(0.5, 0.1, r'$\sigma^2=$'+str(round(np.nanvar(data),3)), transform=axes[x,y].transAxes)
axes[x,y].set_xlabel('Aitchison Distance \n'r'$d_a(\mathbf{\hat{x}}_{PGM},\mathbf{x}^{*})$')

m = 9
x = math.ceil((m+1)/3)-1
y = (m % 3)
data = np.loadtxt(folder+'Ait_distances_'+str(m)+'.txt')
axes[x,y].hist(data, bins = 30)
axes[x,y].annotate('M'+str(m+1), xy=(0.8, 0.9), xycoords="axes fraction", weight='bold')
axes[x,y].text(0.1, 0.9, r'$\mu=$'+str(round(np.nanmean(data),2)), transform=axes[x,y].transAxes)
axes[x,y].text(0.1, 0.8, r'$\sigma^2=$'+str(round(np.nanvar(data),3)), transform=axes[x,y].transAxes)
axes[x,y].set_ylabel('Frequency')
axes[x,y].set_xlabel('Aitchison Distance \n'r'$d_a(\mathbf{\hat{x}}_{PGM},\mathbf{x}^{*})$')


axes[3,1].axis('off')
axes[3,2].axis('off')
plt.savefig('../Figures/PGM_hist.pdf')
plt.show()

# %% [markdown]
# ### ALS

# %%
mixtures = ['M1', 'M2', 'M3', 'M4', 'M5', 'M6', 'M7', 'M8', 'M9', 'M10']
folder = '../Results/NGS_J19_DRK/ALS/'

plt.style.use('stylesheet.mpltstyle_histograms')
fig, axes = plt.subplots(4, 3, figsize = (4.3, 5))

m = 0
x = math.ceil((m+1)/3)-1
y = (m % 3)
data = np.loadtxt(folder+'Ait_distances_'+str(m)+'.txt')
axes[x,y].hist(data, bins = 30)
axes[x,y].annotate('M'+str(m+1), xy=(0.05, 0.9), xycoords="axes fraction", weight='bold')
axes[x,y].text(0.65, 0.9, r'$\mu=$'+str(round(np.nanmean(data),2)), transform=axes[x,y].transAxes)
axes[x,y].text(0.65, 0.8, r'$\sigma^2=$'+str(round(np.nanvar(data),3)), transform=axes[x,y].transAxes)
axes[x,y].set_ylabel('Frequency')

m = 1
x = math.ceil((m+1)/3)-1
y = (m % 3)
data = np.loadtxt(folder+'Ait_distances_'+str(m)+'.txt')
axes[x,y].hist(data, bins = 30)
axes[x,y].annotate('M'+str(m+1), xy=(0.3, 0.9), xycoords="axes fraction", weight='bold')
axes[x,y].text(0.65, 0.9, r'$\mu=$'+str(round(np.nanmean(data),2)), transform=axes[x,y].transAxes)
axes[x,y].text(0.65, 0.8, r'$\sigma^2=$'+str(round(np.nanvar(data),3)), transform=axes[x,y].transAxes)

m = 2
x = math.ceil((m+1)/3)-1
y = (m % 3)
data = np.loadtxt(folder+'Ait_distances_'+str(m)+'.txt')
axes[x,y].hist(data, bins = 30)
axes[x,y].annotate('M'+str(m+1), xy=(0.3, 0.9), xycoords="axes fraction", weight='bold')
axes[x,y].text(0.65, 0.9, r'$\mu=$'+str(round(np.nanmean(data),2)), transform=axes[x,y].transAxes)
axes[x,y].text(0.65, 0.8, r'$\sigma^2=$'+str(round(np.nanvar(data),3)), transform=axes[x,y].transAxes)

m = 3
x = math.ceil((m+1)/3)-1
y = (m % 3)
data = np.loadtxt(folder+'Ait_distances_'+str(m)+'.txt')
axes[x,y].hist(data, bins = 30)
axes[x,y].annotate('M'+str(m+1), xy=(0.3, 0.9), xycoords="axes fraction", weight='bold')
axes[x,y].text(0.65, 0.9, r'$\mu=$'+str(round(np.nanmean(data),2)), transform=axes[x,y].transAxes)
axes[x,y].text(0.65, 0.8, r'$\sigma^2=$'+str(round(np.nanvar(data),3)), transform=axes[x,y].transAxes)
axes[x,y].set_ylabel('Frequency')

m = 4
x = math.ceil((m+1)/3)-1
y = (m % 3)
data = np.loadtxt(folder+'Ait_distances_'+str(m)+'.txt')
axes[x,y].hist(data, bins = 30)
axes[x,y].annotate('M'+str(m+1), xy=(0.3, 0.9), xycoords="axes fraction", weight='bold')
axes[x,y].text(0.65, 0.9, r'$\mu=$'+str(round(np.nanmean(data),2)), transform=axes[x,y].transAxes)
axes[x,y].text(0.65, 0.8, r'$\sigma^2=$'+str(round(np.nanvar(data),3)), transform=axes[x,y].transAxes)

m = 5
x = math.ceil((m+1)/3)-1
y = (m % 3)
data = np.loadtxt(folder+'Ait_distances_'+str(m)+'.txt')
axes[x,y].hist(data, bins = 30)
axes[x,y].annotate('M'+str(m+1), xy=(0.3, 0.9), xycoords="axes fraction", weight='bold')
axes[x,y].text(0.65, 0.9, r'$\mu=$'+str(round(np.nanmean(data),2)), transform=axes[x,y].transAxes)
axes[x,y].text(0.65, 0.8, r'$\sigma^2=$'+str(round(np.nanvar(data),3)), transform=axes[x,y].transAxes)

m = 6
x = math.ceil((m+1)/3)-1
y = (m % 3)
data = np.loadtxt(folder+'Ait_distances_'+str(m)+'.txt')
axes[x,y].hist(data, bins = 30)
axes[x,y].annotate('M'+str(m+1), xy=(0.1, 0.9), xycoords="axes fraction", weight='bold')
axes[x,y].text(0.65, 0.9, r'$\mu=$'+str(round(np.nanmean(data),2)), transform=axes[x,y].transAxes)
axes[x,y].text(0.65, 0.8, r'$\sigma^2=$'+str(round(np.nanvar(data),3)), transform=axes[x,y].transAxes)
axes[x,y].set_ylabel('Frequency')

m = 7
x = math.ceil((m+1)/3)-1
y = (m % 3)
data = np.loadtxt(folder+'Ait_distances_'+str(m)+'.txt')
axes[x,y].hist(data, bins = 30)
axes[x,y].annotate('M'+str(m+1), xy=(0.8, 0.9), xycoords="axes fraction", weight='bold')
axes[x,y].text(0.1, 0.9, r'$\mu=$'+str(round(np.nanmean(data),2)), transform=axes[x,y].transAxes)
axes[x,y].text(0.1, 0.8, r'$\sigma^2=$'+str(round(np.nanvar(data),3)), transform=axes[x,y].transAxes)
axes[x,y].set_xlabel('Aitchison Distance \n'r'$d_a(\mathbf{\hat{x}}_{ALS},\mathbf{x}^{*})$')

m = 8
x = math.ceil((m+1)/3)-1
y = (m % 3)
data = np.loadtxt(folder+'Ait_distances_'+str(m)+'.txt')
axes[x,y].hist(data, bins = 30)
axes[x,y].annotate('M'+str(m+1), xy=(0.05, 0.9), xycoords="axes fraction", weight='bold')
axes[x,y].text(0.5, 0.9, r'$\mu=$'+str(round(np.nanmean(data),2)), transform=axes[x,y].transAxes)
axes[x,y].text(0.5, 0.8, r'$\sigma^2=$'+str(round(np.nanvar(data),3)), transform=axes[x,y].transAxes)
axes[x,y].set_xlabel('Aitchison Distance \n'r'$d_a(\mathbf{\hat{x}}_{ALS},\mathbf{x}^{*})$')

m = 9
x = math.ceil((m+1)/3)-1
y = (m % 3)
data = np.loadtxt(folder+'Ait_distances_'+str(m)+'.txt')
axes[x,y].hist(data, bins = 30)
axes[x,y].annotate('M'+str(m+1), xy=(0.3, 0.9), xycoords="axes fraction", weight='bold')
axes[x,y].text(0.65, 0.9, r'$\mu=$'+str(round(np.nanmean(data),2)), transform=axes[x,y].transAxes)
axes[x,y].text(0.65, 0.8, r'$\sigma^2=$'+str(round(np.nanvar(data),3)), transform=axes[x,y].transAxes)
axes[x,y].set_ylabel('Frequency')
axes[x,y].set_xlabel('Aitchison Distance \n'r'$d_a(\mathbf{\hat{x}}_{ALS},\mathbf{x}^{*})$')


axes[3,1].axis('off')
axes[3,2].axis('off')
plt.savefig('../Figures/ALS_hist.pdf')
plt.show()
